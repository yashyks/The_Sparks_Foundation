# %% [markdown]
# # Task_5 - To explore Business Analytics
# # Yash Kumar Sharma

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"C:\Users\Yash Kumar Sharma\Downloads\SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
corr=df.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corr,annot=True)

# %% [markdown]
# Total rows and column

# %%
Total_rows = len(df.axes[0])
Total_cols = len(df.axes[1])
print("Total no. of rows :", Total_rows)
print("Total no. of Columns :", Total_cols)
# Out:
# Total no. of rows : 9994
# Total no. of Columns : 13

# %% [markdown]
# City Wise count

# %%
City_count = df['City'].value_counts()
print(City_count)
#Counting total no. of cities
Total_city = df['City'].nunique()
print("Total no. of cities:", Total_city)
# Out:
# New York City    915
# Los Angeles      747
# Philadelphia     537
# San Francisco    510
# Seattle          428
#                 ...
# Yucaipa            1
# Iowa City          1
# La Quinta          1
# Jupiter            1
# Whittier           1
# Name: City, Length: 531, dtype: int64
# Total no. of cities: 531

# %% [markdown]
# State wise count

# %%
State_count = df['State'].value_counts()
print(State_count)
#Counting total no. of States
Total_state = df['State'].nunique()
print("Total no. of States:", Total_state)
# Out:
# California              2001
# New York                1128
# Texas                    985
# Pennsylvania             587
# Washington               506
# Illinois                 492
# Ohio                     469
# Florida                  383
# Michigan                 255
# North Carolina           249
# Arizona                  224
# Virginia                 224
# Georgia                  184
# Tennessee                183
# Colorado                 182
# Indiana                  149
# Kentucky                 139
# Massachusetts            135
# New Jersey               130
# Oregon                   124
# Wisconsin                110
# Maryland                 105
# Delaware                  96
# Minnesota                 89
# Connecticut               82
# Oklahoma                  66
# Missouri                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              56
# Utah                      53
# Mississippi               53
# ...

# %% [markdown]
# Category wise count

# %%
catg = df['Category'].value_counts()
print(catg)
Total_catg = df['Category'].nunique()
print("Total no. of States:", Total_catg)
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64
# Total no. of States: 3

# %%
plt.figure(figsize = (11,7))
df['Category'].value_counts().plot(kind = 'bar')
plt.xticks(rotation = 0)
# Out:
# (array([0, 1, 2]), <a list of 3 Text xticklabel objects>)

# %%
fig = plt.figure(figsize= (10,7))
df['Sub-Category'].value_counts().plot.pie(autopct = '%.2f',shadow = False)

# %% [markdown]
# Plotting Region Vs Category

# %%
pd.crosstab(df['Region'],df['Category']).plot(kind = 'bar',figsize=(15,10))

# %% [markdown]
# Plotting Region Vs Subcategory

# %%
pd.crosstab(df['Region'],df['Sub-Category']).plot(kind = 'bar',figsize=(15,10))

# %% [markdown]
# Profit

# %%
profit = df['Profit']
profit
# Out:
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64

# %%
# Maximum Profit
df.loc[df['Profit'].idxmax()]
# Out:
# Ship Mode       Standard Class
# Segment              Corporate
# Country          United States
# City                 Lafayette
# State                  Indiana
# Postal Code              47905
# Region                 Central
# Category            Technology
# Sub-Category           Copiers
# Sales                    17500
# Quantity                     5
# Discount                     0
# Profit                 8399.98
# Name: 6826, dtype: object

# %% [markdown]
# Loss

# %%
loss = df[df['Profit']< 0]
loss
# Out:
#            Ship Mode      Segment        Country             City  \
# 3     Standard Class     Consumer  United States  Fort Lauderdale
# 14    Standard Class  Home Office  United States       Fort Worth
# 15    Standard Class  Home Office  United States       Fort Worth
# 23      Second Class     Consumer  United States     Philadelphia
# 27    Standard Class     Consumer  United States     Philadelphia
# ...              ...          ...            ...              ...
# 9920  Standard Class    Corporate  United States            Bryan
# 9921  Standard Class  Home Office  United States            Akron
# 9931  Standard Class     Consumer  United States   San Bernardino
# 9937    Second Class    Corporate  United States      Los Angeles
# 9962     First Class  Home Office  United States          Houston
#
#              State  Postal Code   Region         Category Sub-Category  \
# 3          Florida        33311    South        Furniture       Tables
# ...

# %%
print("total size of data")
df.shape
# Out:
# total size of data
# (9994, 13)

# %%
print("Total size of Loss data:")
loss.shape
# Out:
# Total size of Loss data:
# (1871, 13)

# %%
#loss in data
1871/9994 * 100
# Out:
# 18.721232739643785

# %% [markdown]
# Hence loss is in 18% data

# %% [markdown]
# City wise profit

# %%
City_Profit = df.groupby('City').sum()['Profit']
print("City wise Profit in Ascending Order: \n", City_Profit)
# Out:
# City wise Profit in Ascending Order:
#  City
# Aberdeen          6.6300
# Abilene          -3.7584
# Akron          -186.6356
# Albuquerque     634.0881
# Alexandria      318.6183
#                  ...
# Woonsocket       78.6791
# Yonkers        2767.7557
# York           -102.1692
# Yucaipa          13.2080
# Yuma           -465.9909
# Name: Profit, Length: 531, dtype: float64

# %%
city_sorted1 = City_Profit.sort_values(ascending = False).head()
#plot
fig,axes = plt.subplots(1,2, figsize = (15,5))
city_sorted1.plot(kind ='bar', ax = axes[0])
axes[0].tick_params(labelrotation = 90)
axes[0].set_title("Maximum City Profit (Top 5)")
city_sorted2 = City_Profit.sort_values(ascending = True).head()
city_sorted2.head().plot(kind='bar',ax = axes[1])
plt.xticks(rotation = 90)
plt.title("Minimum City Profit (Bottom 5)")
# Out:
# Text(0.5, 1.0, 'Minimum City Profit (Bottom 5)')

# %% [markdown]
# State wise profit

# %%
State_Profit = df.groupby('State').sum()['Profit']
print("State wise profit:\n",State_Profit)
# Out:
# State wise profit:
#  State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
State_Profit.sort_values(ascending = False)
#plot
plt.figure(figsize =(15,4))
sns.barplot(x = State_Profit.index, y = State_Profit.values)
plt.xticks(rotation =90)
plt.title("State Wise Profit")
# Out:
# Text(0.5, 1.0, 'State Wise Profit')

# %% [markdown]
# Region wise

# %%
Region_profit = df.groupby('Region').sum()['Profit']
print("Region wise profit:\n",Region_profit)
# Out:
# Region wise profit:
#  Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
#Display Region wise profit in maximum to minimum order
Region_profit.sort_values(ascending = False)
#Plot
plt.pie(Region_profit, labels = Region_profit.index, autopct= "%.2f", explode = (0.05,0.05,0.05,0.05),radius=1.3)
fig= plt.gcf()

# %% [markdown]
# ## SALES

# %% [markdown]
# City Wise

# %%
City_Sale = df.groupby('City').sum()['Sales']
City_Sale
# Out:
# City
# Aberdeen         25.500
# Abilene           1.392
# Akron          2729.986
# Albuquerque    2220.160
# Alexandria     5519.570
#                  ...
# Woonsocket      195.550
# Yonkers        7657.666
# York            817.978
# Yucaipa          50.800
# Yuma            840.865
# Name: Sales, Length: 531, dtype: float64

# %%
Sorted_City_Sale = City_Sale.sort_values(ascending = False).head(12)
#Plot
plt.pie(Sorted_City_Sale, labels = Sorted_City_Sale.index, autopct= "%.2f",shadow = False, radius = 1.5)
fig= plt.gcf()

# %% [markdown]
# Region Wise

# %%
Region_Sale = df.groupby("Region").sum()['Sales']
Region_Sale
# Out:
# Region
# Central    501239.8908
# East       678781.2400
# South      391721.9050
# West       725457.8245
# Name: Sales, dtype: float64

# %%
Region_sorted = Region_Sale.sort_values(ascending = False)
##plot
plt.pie(Region_sorted, labels = Region_sorted.index, autopct= "%.2f",shadow = False, radius = 1.5)
fig= plt.gcf()

# %% [markdown]
# State Wise

# %%
State_Sale = df.groupby('State').sum()['Sales']
State_Sale
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
Sorted_state_Sale = State_Sale.sort_values(ascending = False).head(15)
#Plot
plt.pie(Sorted_state_Sale, labels = Sorted_state_Sale.index, autopct= "%.1f",shadow = False, radius = 1.5)
fig= plt.gcf()

# %% [markdown]
# ## Category wise sales

# %%
Catg_Sale = df.groupby('Category').sum()['Sales']
Catg_Sale
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
Sorted_Catg_Sale = Catg_Sale.sort_values(ascending = False)
##Plot
plt.pie(Sorted_Catg_Sale, labels = Sorted_Catg_Sale.index, autopct= "%.1f",shadow = False, radius = 1.5)
fig= plt.gcf()

# %% [markdown]
# ## Sub category wise sales

# %%
Scatg = df.groupby('Sub-Category').sum()['Sales']
Scatg
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
Sorted_Scatg_Sale = Scatg.sort_values(ascending = False)
Sorted_Scatg_Sale
##Plot
plt.pie(Sorted_Scatg_Sale, labels = Sorted_Scatg_Sale.index, autopct= "%.1f",shadow = False, radius = 2.0)
fig= plt.gcf()
